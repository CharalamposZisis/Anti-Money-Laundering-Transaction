# %%
import pandas as pd

df = pd.read_csv(
    "/Workspace/Users/xarisban@gmail.com/Anti-Money-Laundering-Transaction/kaggle/SAML-D.csv"
)

df.head()

# %%
df.info()

# %%
df.isnull().sum()

# %%
# %pip install autoviz
from autoviz import AutoViz_Class
AV = AutoViz_Class()

filename = "/Workspace/Users/xarisban@gmail.com/Anti-Money-Laundering-Transaction/kaggle/SAML-D.csv"
target_variable = "Is_laundering"

dft = AV.AutoViz(
    filename,
    sep=",",
    depVar=target_variable,
    dfte=None,
    header=0,
    verbose=1,
    lowess=False,
    chart_format="svg",
    max_rows_analyzed=150000,
    max_cols_analyzed=30,
    save_plot_dir=None
)

# %% [markdown]
# # Univariate analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("darkgrid")

numerical_columns = df.select_dtypes(include=["int64", "float64"]).columns

plt.figure(figsize=(14, len(numerical_columns) * 3))
for idx, feature in enumerate(numerical_columns, 1):
    plt.subplot(len(numerical_columns), 2, idx)
    sns.histplot(df[feature], kde=True)
    plt.title(f"{feature} | Skewness: {round(df[feature].skew(), 2)}")

plt.tight_layout()
plt.show()
